# %%
import pandas as pd
from utils import *

# %%
generateData(start='2018-08-07',end='2018-08-08')
# Out:
# E:\learning\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# E:\learning\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# ...

# %%
df[(df['Time']>=pd.datetime(2018,8,4))& (df['Time']<pd.datetime(2018,8,5))]
# Out:
#              Day Timestamp UTC ms                Time Place     Room  \
# 973   2018-08-04    1533312000000 2018-08-04 00:00:00  home  bedroom
# 974   2018-08-04    1533314239285 2018-08-04 00:37:19  home  bedroom
# 975   2018-08-04    1533314562483 2018-08-04 00:42:42  home  bedroom
# 976   2018-08-04    1533317307400 2018-08-04 01:28:27  home  bedroom
# 977   2018-08-04    1533334291715 2018-08-04 06:11:31  home  bedroom
# 978   2018-08-04    1533335893041 2018-08-04 06:38:13  home  bedroom
# 979   2018-08-04    1533336866842 2018-08-04 06:54:26   NaN      NaN
# 980   2018-08-04    1533337601349 2018-08-04 07:06:41   外婆家      NaN
# 981   2018-08-04    1533338032300 2018-08-04 07:13:52   外婆家      NaN
# 982   2018-08-04    1533338175859 2018-08-04 07:16:15   外婆家      NaN
# 983   2018-08-04    1533340017570 2018-08-04 07:46:57   NaN      NaN
# 984   2018-08-04    1533342843548 2018-08-04 08:34:03  home      NaN
# 985   2018-08-04    1533343263252 2018-08-04 08:41:03  home      NaN
# ...

# %%
tmp
# Out:
# Time
# 2018-07-20    -6.372333
# 2018-07-21    22.998728
# 2018-07-22    29.708273
# 2018-07-23    25.304784
# 2018-07-24     2.319011
# 2018-07-25    34.879598
# 2018-07-26    36.946539
# 2018-07-27    32.714486
# 2018-07-28    45.803540
# 2018-07-29    35.851383
# 2018-07-30    44.944851
# 2018-07-31    17.717499
# 2018-08-01    12.273711
# 2018-08-02    -4.920312
# 2018-08-03     8.743926
# 2018-08-04    53.970479
# 2018-08-05    27.068159
# 2018-08-06    16.216374
# 2018-08-07    13.268757
# 2018-08-08    26.908554
# Name: point, dtype: float64

# %%
[pd.to_datetime(x) for x in tmp.index.tolist()]
# Out:
# [Timestamp('2018-07-20 00:00:00'),
#  Timestamp('2018-07-21 00:00:00'),
#  Timestamp('2018-07-22 00:00:00'),
#  Timestamp('2018-07-23 00:00:00'),
#  Timestamp('2018-07-24 00:00:00'),
#  Timestamp('2018-07-25 00:00:00'),
#  Timestamp('2018-07-26 00:00:00'),
#  Timestamp('2018-07-27 00:00:00'),
#  Timestamp('2018-07-28 00:00:00'),
#  Timestamp('2018-07-29 00:00:00'),
#  Timestamp('2018-07-30 00:00:00'),
#  Timestamp('2018-07-31 00:00:00'),
#  Timestamp('2018-08-01 00:00:00'),
#  Timestamp('2018-08-02 00:00:00'),
#  Timestamp('2018-08-03 00:00:00'),
#  Timestamp('2018-08-04 00:00:00'),
#  Timestamp('2018-08-05 00:00:00'),
#  Timestamp('2018-08-06 00:00:00'),
#  Timestamp('2018-08-07 00:00:00'),
#  Timestamp('2018-08-08 00:00:00')]

# %%
dailyPoint[[pd.to_datetime(x) for x in tmp.index.tolist()]] = tmp.values

# %%
[x.strftime('%Y-%m-%d') for x in dailyPoint.index]
# Out:
# ['2018-01-01',
#  '2018-01-02',
#  '2018-01-03',
#  '2018-01-04',
#  '2018-01-05',
#  '2018-01-06',
#  '2018-01-07',
#  '2018-01-08',
#  '2018-01-09',
#  '2018-01-10',
#  '2018-01-11',
#  '2018-01-12',
#  '2018-01-13',
#  '2018-01-14',
#  '2018-01-15',
#  '2018-01-16',
#  '2018-01-17',
#  '2018-01-18',
#  '2018-01-19',
#  '2018-01-20',
#  '2018-01-21',
#  '2018-01-22',
#  '2018-01-23',
#  '2018-01-24',
#  '2018-01-25',
#  '2018-01-26',
#  '2018-01-27',
#  '2018-01-28',
#  '2018-01-29',
#  '2018-01-30',
#  '2018-01-31',
#  '2018-02-01',
#  '2018-02-02',
#  '2018-02-03',
#  '2018-02-04',
#  '2018-02-05',
#  '2018-02-06',
#  '2018-02-07',
#  '2018-02-08',
#  '2018-02-09',
#  '2018-02-10',
#  '2018-02-11',
#  '2018-02-12',
#  '2018-02-13',
#  '2018-02-14',
#  '2018-02-15',
#  '2018-02-16',
#  '2018-02-17',
#  '2018-02-18',
#  '2018-02-19',
#  '2018-02-20',
#  '2018-02-21',
#  '2018-02-22',
#  '2018-02-23',
#  '2018-02-24',
#  '2018-02-25',
#  '2018-02-26',
#  '2018-02-27',
# ...

# %%
df_ = utils.generateData(start='2018-08-04',end='2018-08-05')
# Out:
# E:\learning\Anaconda3\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# E:\learning\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# ...

# %%
df = utils.df
df.head()
# Out:
#           Day Timestamp UTC ms                Time          Place Room  \
# 0  2018-07-20    1532046429168 2018-07-20 08:27:09  上海市闸北区晋城路663弄  NaN
# 1  2018-07-20    1532046429207 2018-07-20 08:27:09  上海市闸北区晋城路663弄  NaN
# 2  2018-07-20    1532049772475 2018-07-20 09:22:52  上海市闸北区晋城路663弄  NaN
# 3  2018-07-20    1532049905605 2018-07-20 09:25:05  上海市闸北区晋城路663弄  NaN
# 4  2018-07-20    1532049961430 2018-07-20 09:26:01  上海市闸北区晋城路663弄  NaN
#
#                Activity    Activity Category  Duration ms  Steps    Move  \
# 0    phone-Smarter Time        Personal Life           39      0  NOMOVE
# 1             phone-浏览器  Art & Entertainment      3343268      0  NOMOVE
# 2            phone-手机淘宝               Chores       133130      0  NOMOVE
# 3             phone-浏览器  Art & Entertainment        55825      0  NOMOVE
# 4  phone-Google Play 商店  Art & Entertainment       125092      0  NOMOVE
#
#       Device  Duration_hrs    color     value
# 0  Letv X500      0.000011  #FF00FF  0.000000
# ...

# %%
utils.dailyPoint
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-307e41614ad5> in <module>()
# ----> 1 utils.dailyPoint
#
# NameError: name 'utils' is not defined

# %%
utils.valueDict
# Out:
# {'Art & Entertainment': -3.0,
#  'Chores': 1.0,
#  'Health & Hygiene': 1.0,
#  'Hobbies': 1.0,
#  'No category': 0.0,
#  'Personal Life': 0.0,
#  'Professional Life': 5.0,
#  'Resting': -1.0,
#  'Social': -2.0,
#  'Sport & Fitness': 1.0,
#  'Transport': 0.0}

# %%
df = utils.df
df[(df['Time'] >= pd.to_datetime('2018-08-04', format='%Y-%m-%d'))& \
  (df['Time'] < pd.to_datetime('2018-08-05', format='%Y-%m-%d'))]
# Out:
#              Day Timestamp UTC ms                Time Place     Room  \
# 973   2018-08-04    1533312000000 2018-08-04 00:00:00  home  bedroom
# 974   2018-08-04    1533314239285 2018-08-04 00:37:19  home  bedroom
# 975   2018-08-04    1533314562483 2018-08-04 00:42:42  home  bedroom
# 976   2018-08-04    1533317307400 2018-08-04 01:28:27  home  bedroom
# 977   2018-08-04    1533334291715 2018-08-04 06:11:31  home  bedroom
# 978   2018-08-04    1533335893041 2018-08-04 06:38:13  home  bedroom
# 979   2018-08-04    1533336866842 2018-08-04 06:54:26   NaN      NaN
# 980   2018-08-04    1533337601349 2018-08-04 07:06:41   外婆家      NaN
# 981   2018-08-04    1533338032300 2018-08-04 07:13:52   外婆家      NaN
# 982   2018-08-04    1533338175859 2018-08-04 07:16:15   外婆家      NaN
# 983   2018-08-04    1533340017570 2018-08-04 07:46:57   NaN      NaN
# 984   2018-08-04    1533342843548 2018-08-04 08:34:03  home      NaN
# 985   2018-08-04    1533343263252 2018-08-04 08:41:03  home      NaN
# ...

# %%
dailyPoint
tmp
# Out:
# 2018-01-01    0
# 2018-01-02    0
# 2018-01-03    0
# 2018-01-04    0
# 2018-01-05    0
# 2018-01-06    0
# 2018-01-07    0
# 2018-01-08    0
# 2018-01-09    0
# 2018-01-10    0
# 2018-01-11    0
# 2018-01-12    0
# 2018-01-13    0
# 2018-01-14    0
# 2018-01-15    0
# 2018-01-16    0
# 2018-01-17    0
# 2018-01-18    0
# 2018-01-19    0
# 2018-01-20    0
# 2018-01-21    0
# 2018-01-22    0
# 2018-01-23    0
# 2018-01-24    0
# 2018-01-25    0
# 2018-01-26    0
# 2018-01-27    0
# 2018-01-28    0
# 2018-01-29    0
# 2018-01-30    0
#              ..
# 2018-12-02    0
# 2018-12-03    0
# 2018-12-04    0
# 2018-12-05    0
# 2018-12-06    0
# 2018-12-07    0
# 2018-12-08    0
# 2018-12-09    0
# 2018-12-10    0
# 2018-12-11    0
# 2018-12-12    0
# 2018-12-13    0
# 2018-12-14    0
# 2018-12-15    0
# 2018-12-16    0
# 2018-12-17    0
# 2018-12-18    0
# 2018-12-19    0
# 2018-12-20    0
# 2018-12-21    0
# 2018-12-22    0
# 2018-12-23    0
# 2018-12-24    0
# 2018-12-25    0
# ...

# %%
00tmp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1befcb9b28e2> in <module>()
# ----> 1 tmp
#
# NameError: name 'tmp' is not defined

# %%
df.tail()
# Out:
#              Day Timestamp UTC ms                Time      Place Room  \
# 1297  2018-08-08    1533720155321 2018-08-08 17:22:35  复旦大学第二教学楼  NaN
# 1298  2018-08-08    1533720222041 2018-08-08 17:23:42  复旦大学第二教学楼  NaN
# 1299  2018-08-08    1533721153771 2018-08-08 17:39:13  复旦大学第二教学楼  NaN
# 1300  2018-08-08    1533721589427 2018-08-08 17:46:29  复旦大学第二教学楼  NaN
# 1301  2018-08-08    1533721675247 2018-08-08 17:47:55  复旦大学第二教学楼  NaN
#
#                 Activity    Activity Category  Duration ms  Steps    Move  \
# 1297            phone-微信               Social        66720      0  NOMOVE
# 1298  study-deeplearning    Professional Life       931730      0  NOMOVE
# 1299            phone-微信               Social       435656      0  NOMOVE
# 1300          phone-知乎日报  Art & Entertainment        85820      0  NOMOVE
# 1301                 nap              Resting      1748958      0  NOMOVE
#
#          Device  Duration_hrs    color     point
# 1297  Letv X500      0.018533  #5B00AE -0.055600
# ...
